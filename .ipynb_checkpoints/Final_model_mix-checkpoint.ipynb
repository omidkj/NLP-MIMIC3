# %%
import pandas as pd
import numpy as np
import math as mt
import os.path
import copy
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
# %matplotlib inline

# %%
final_data_with_icd_codes = pd.read_csv('final_data_with_icd_codes.csv', header = 0)

# %%
final_data_with_icd_codes = final_data_with_icd_codes.drop('Unnamed: 0', axis = 1)

# %%
final_data_with_icd_codes[(final_data_with_icd_codes['target'] == 1) & (final_data_with_icd_codes['cui_exist'] == 0)
                         & (final_data_with_icd_codes['negation_exist'] == 0)]
# Out:
#       cui_exist  negation_exist  uncertainty_exist  hadm_id  icd_code  \
# 72            0               0                  0   185880     41519
# 354           0               0                  0   129882     41519
# 363           0               0                  0   141664     41519
# 370           0               0                  0   147390     41519
# 393           0               0                  0   197786     41519
# 481           0               0                  0   153323     41519
# 579           0               0                  0   129707     41519
# 606           0               0                  0   108486     41519
# 648           0               0                  0   129556     41511
# 653           0               0                  0   106005     41519
# 719           0               0                  0   167098     41512
# 748           0               0                  0   124762     41511
# 786           0               0                  0   198062     41511
# 828           0               0                  0   177717     41519
# 931           0               0                  0   133614     41519
# 951           0               0                  0   181712     41519
# 952           0               0                  0   146001     41511
# 961           0               0                  0   129888     41519
# 1009          0               0                  0   158373     41511
# 1054          0               0                  0   141903     41512
# 1126          0               0                  0   151093     41519
# 1135          0               0                  0   110147     41519
# 1172          0               0                  0   175359     41519
# 1202          0               0                  0   137513     41511
# 1279          0               0                  0   163597     41519
# 1313          0               0                  0   107085     41511
# 1356          0               0                  0   168918     41512
# 1362          0               0                  0   126085     41511
# 1365          0               0                  0   168599     41519
# 1400          0               0                  0   127420     41519
# ...         ...             ...                ...      ...       ...
# 3445          0               0                  0   179842     41519
# 3463          0               0                  0   106296     41519
# 3480          0               0                  0   176953     41519
# 3500          0               0                  0   173920     41519
# 3562          0               0                  0   129744     41519
# 3568          0               0                  0   158983     41512
# 3685          0               0                  0   186098     41512
# 3697          0               0                  0   139712     41519
# 3710          0               0                  0   128939     41519
# 3809          0               0                  0   105899     41511
# 3827          0               0                  0   120435     41519
# 3916          0               0                  0   197965     41519
# 4078          0               0                  0   186506     41519
# 4089          0               0                  0   154119     41512
# 4113          0               0                  0   143994     41511
# 4134          0               0                  0   188166     41519
# 4147          0               0                  0   122833     41519
# 4212          0               0                  0   171444     41519
# 4220          0               0                  0   141048     41519
# 4224          0               0                  0   169280     41512
# 4228          0               0                  0   183362     41511
# 4250          0               0                  0   169960     41512
# 4480          0               0                  0   196745     41519
# 4489          0               0                  0   124038     41519
# 4506          0               0                  0   185620     41519
# 4650          0               0                  0   133296     41519
# 4699          0               0                  0   108289     41519
# 4715          0               0                  0   118521     41511
# 4716          0               0                  0   191134     41519
# 4731          0               0                  0   176817     41512
#
#       seq_number  target
# 72             1       1
# 354            2       1
# 363            2       1
# 370            2       1
# 393            3       1
# 481            1       1
# 579            2       1
# 606            7       1
# 648            2       1
# 653            2       1
# 719            5       1
# 748            2       1
# 786            2       1
# 828            2       1
# 931            1       1
# 951            6       1
# 952            2       1
# 961            1       1
# 1009           5       1
# 1054           6       1
# 1126           7       1
# 1135           1       1
# 1172           1       1
# 1202           2       1
# 1279           3       1
# 1313           3       1
# 1356           3       1
# 1362           2       1
# 1365           1       1
# 1400           3       1
# ...          ...     ...
# 3445           2       1
# 3463           3       1
# 3480           3       1
# 3500           6       1
# 3562           3       1
# 3568           3       1
# 3685           6       1
# 3697           4       1
# 3710           1       1
# 3809           2       1
# 3827           1       1
# 3916           3       1
# 4078           2       1
# 4089           2       1
# 4113          11       1
# 4134           1       1
# 4147           1       1
# 4212           3       1
# 4220           2       1
# 4224           3       1
# 4228           6       1
# 4250           9       1
# 4480           5       1
# 4489           3       1
# 4506           1       1
# 4650           1       1
# 4699           2       1
# 4715           2       1
# 4716           2       1
# 4731           2       1
#
# [98 rows x 7 columns]

# %%
final_data = pd.read_csv('final_data.csv', header = 0)

# %%
final_data=final_data.drop('Unnamed: 0', axis = 1)

# %%
final_data.head()
# Out:
#    cui_exist  negation_exist  uncertainty_exist  hadm_id  seq_number  target
# 0          0               0                  0   111544          16       0
# 1          1               0                  0   166737           2       1
# 2          0               0                  0   137804          15       0
# 3          1               1                  0   162201           2       0
# 4          1               1                  0   168769           6       0

# %%
X_data = final_data.drop('target', axis = 1)
labels = final_data['target']

# %%
train_x, test_x, train_y, test_y  = train_test_split(X_data, labels, test_size=0.4, stratify = labels, random_state=110)

# %%
train_x, eval_x, train_y, eval_y  = train_test_split(train_x, train_y, test_size=0.2, stratify = train_y, random_state=110)

# %%
col_names = list(train_x.columns)
col_names.remove('hadm_id')
feature_columns = [tf.feature_column.numeric_column(key = key, shape=[1]) for key in col_names]

# %%
model_dir = os.path.join('.', 'model', 'dnn_classifier_2_layers_32_16_drop02')

# %%
model = tf.estimator.DNNClassifier(
    feature_columns=feature_columns,
    hidden_units=[32,16],
    dropout=0.2,
    model_dir=model_dir,
    n_classes=2,
    optimizer=tf.train.ProximalAdagradOptimizer(
      learning_rate=0.001,
      l1_regularization_strength=0.001))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './model/dnn_classifier_2_layers_32_16_drop02', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f75961c5160>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
train_input_fn = tf.estimator.inputs.pandas_input_fn(train_x, y=train_y, shuffle=True)
eval_input_fn = tf.estimator.inputs.pandas_input_fn(eval_x, y=eval_y, shuffle=True)

# %%
train_spec = tf.estimator.TrainSpec(input_fn=train_input_fn, max_steps=50000)

eval_spec = tf.estimator.EvalSpec(input_fn=eval_input_fn)

# %%
tf.estimator.train_and_evaluate(model, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 600 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 72.46524, step = 1
# INFO:tensorflow:Saving checkpoints for 18 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 59.611267.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:37:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-18
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:37:46
# INFO:tensorflow:Saving dict for global step 18: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.69914246, auc_precision_recall = 0.17404222, average_loss = 0.49741074, global_step = 18, label/mean = 0.07665505, loss = 57.102753, precision = 0.0, prediction/mean = 0.37156203, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-18
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-18
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 18 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 63.052193, step = 19
# INFO:tensorflow:Saving checkpoints for 36 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 58.27673.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:37:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-36
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:37:48
# INFO:tensorflow:Saving dict for global step 36: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.6965266, auc_precision_recall = 0.17376089, average_loss = 0.47619623, global_step = 36, label/mean = 0.07665505, loss = 54.667328, precision = 0.0, prediction/mean = 0.35472655, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step
recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 414: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-414
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-414
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 414 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 40.34381, step = 415
# INFO:tensorflow:Saving checkpoints for 432 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 36.53301.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:38:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-432
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:38:27
# INFO:tensorflow:Saving dict for global step 432: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.7217839, auc_precision_recall = 0.18546085, average_loss = 0.31311208, global_step = 432, label/mean = 0.07665505, loss = 35.945267, precision = 0.0, prediction/mean = 0.2070363, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 432: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-432
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-432
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 432 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 53.957275, step = 433
# INFO:tensorflow:Saving checkpoints for 450 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 39.164948.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:38:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-450
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:38:29
# INFO:tensorflow:Saving dict for global step 450: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.7408233, auc_precision_recall = 0.36378253, average_loss = 0.31037202, global_step = 450, label/mean = 0.07665505, loss = 35.630707, precision = 0.0, prediction/mean = 0.20404533, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 450: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-450
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-450
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 450 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 43.147873, step = 451
# INFO:tensorflow:Saving checkpoints for 468 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 44.036823.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:38:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-468
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:38:31
# INFO:tensorflow:Saving dict for global step 468: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.7217839, auc_precision_recall = 0.18546087, average_loss = 0.30773923, global_step = 468, label/mean = 0.07665505, loss = 35.328465, precision = 0.0, prediction/mean = 0.20116751, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 468: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-468
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-468
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 468 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 50.673454, step = 469
# INFO:tensorflow:Saving checkpoints for 486 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 39.182167.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:38:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-486
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:38:33
# INFO:tensorflow:Saving dict for global step 486: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.7406947, auc_precision_recall = 0.36376667, average_loss = 0.30525762, global_step = 486, label/mean = 0.07665505, loss = 35.04357, precision = 0.0, prediction/mean = 0.19842263, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 486: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-486
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-486
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 486 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 39.471066, step = 487
# INFO:tensorflow:Saving checkpoints for 504 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 43.56639.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# ...
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-936
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 936 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 34.04868, step = 937
# INFO:tensorflow:Saving checkpoints for 954 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 48.48548.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:39:19
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-954
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:39:19
# INFO:tensorflow:Saving dict for global step 954: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.7993996, auc_precision_recall = 0.502007, average_loss = 0.26635668, global_step = 954, label/mean = 0.07665505, loss = 30.577747, precision = 0.0, prediction/mean = 0.15121877, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 954: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-954
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-954
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 954 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 38.908035, step = 955
# INFO:tensorflow:Saving checkpoints for 972 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 30.419191.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:39:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-972
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:39:21
# INFO:tensorflow:Saving dict for global step 972: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.8000429, auc_precision_recall = 0.5020804, average_loss = 0.2653959, global_step = 972, label/mean = 0.07665505, loss = 30.46745, precision = 0.0, prediction/mean = 0.14993572, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 972: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-972
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-972
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 972 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 44.498703, step = 973
# INFO:tensorflow:Saving checkpoints for 990 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 27.567863.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:39:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-990
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:39:23
# INFO:tensorflow:Saving dict for global step 990: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.7818183, auc_precision_recall = 0.4875906, average_loss = 0.26452205, global_step = 990, label/mean = 0.07665505, loss = 30.367132, precision = 0.0, prediction/mean = 0.14879869, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 990: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-990
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-990
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 990 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 33.5383, step = 991
# INFO:tensorflow:Saving checkpoints for 1008 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 31.629063.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:39:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1008
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:39:24
# INFO:tensorflow:Saving dict for global step 1008: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.79862785, auc_precision_recall = 0.50189865, average_loss = 0.26366827, global_step = 1008, label/mean = 0.07665505, loss = 30.269115, precision = 0.0, prediction/mean = 0.14766727, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1008: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1008
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1008
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1008 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 36.38291, step = 1009
# INFO:tensorflow:Saving checkpoints for 1026 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 34.666515.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:39:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1026
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:39:26
# INFO:tensorflow:Saving dict for global step 1026: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.8024443, auc_precision_recall = 0.5026134, average_loss = 0.2628386, global_step = 1026, label/mean = 0.07665505, loss = 30.17387, precision = 0.0, prediction/mean = 0.14653689, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1026: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1026
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1026
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1026 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 35.586037, step = 1027
# INFO:tensorflow:Saving checkpoints for 1044 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 33.243767.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:39:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1044
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:39:28
# INFO:tensorflow:Saving dict for global step 1044: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.79862785, auc_precision_recall = 0.5019285, average_loss = 0.26206577, global_step = 1044, label/mean = 0.07665505, loss = 30.08515, precision = 0.0, prediction/mean = 0.14551674, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1044: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1044
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1044
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1044 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 34.24312, step = 1045
# INFO:tensorflow:Saving checkpoints for 1062 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 39.726967.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:39:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1062
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:39:30
# INFO:tensorflow:Saving dict for global step 1062: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.7805317, auc_precision_recall = 0.4874525, average_loss = 0.26127943, global_step = 1062, label/mean = 0.07665505, loss = 29.994879, precision = 0.0, prediction/mean = 0.14444925, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1062: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1062
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1062
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1062 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 39.92902, step = 1063
# INFO:tensorflow:Saving checkpoints for 1080 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 33.42081.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:39:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1080
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:39:32
# INFO:tensorflow:Saving dict for global step 1080: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.80184394, auc_precision_recall = 0.5025522, average_loss = 0.26050878, global_step = 1080, label/mean = 0.07665505, loss = 29.906408, precision = 0.0, prediction/mean = 0.14338054, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1080: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1080
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1080
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1080 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:loss = 34.71801, step = 1081
# INFO:tensorflow:Saving checkpoints for 1098 into ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt.
# INFO:tensorflow:Loss for final step: 33.366695.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-07:39:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1098
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-07:39:33
# INFO:tensorflow:Saving dict for global step 1098: accuracy = 0.92334497, accuracy_baseline = 0.92334497, auc = 0.80227274, auc_precision_recall = 0.5025821, average_loss = 0.25978342, global_step = 1098, label/mean = 0.07665505, loss = 29.823135, precision = 0.0, prediction/mean = 0.14242314, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1098: ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1098
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model/dnn_classifier_2_layers_32_16_drop02/model.ckpt-1098
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
test_input_fn = tf.estimator.inputs.pandas_input_fn(test_x, shuffle=False)

# %%
##estimator.predict(test_input_fn)

# %% [markdown]
# #### Gaussian Naive Bayes Classifier with Negation and Uncertainty

# %%
tr_x = train_x.drop('hadm_id', axis = 1)

# %%
ts_x = test_x.drop('hadm_id', axis = 1)

# %%
gnb = GaussianNB()

# %%
prY = gnb.fit(tr_x, train_y).predict(ts_x)

# %%
prY_prob = gnb.fit(tr_x, train_y).predict_proba(ts_x)

# %%
confusion_matrix(test_y, prY)

# %%
fpr, tpr, _ = metrics.roc_curve(np.array(test_y), prY_prob[:,1])

# %%
auc = metrics.auc(fpr,tpr)
auc

# %%
plt.plot(fpr, tpr)

# %% [markdown]
# #### Gaussian Naive Bayes Classifier without Negation and Uncertainty

# %%
tr_x_n = train_x.drop(['hadm_id', 'negation_exist', 'uncertainty_exist'], axis = 1)

# %%
ts_x_n = test_x.drop(['hadm_id', 'negation_exist', 'uncertainty_exist'], axis = 1)

# %%
gnb = GaussianNB()

# %%
prY = gnb.fit(tr_x_n, train_y).predict(ts_x_n)

# %%
prY_prob = gnb.fit(tr_x_n, train_y).predict_proba(ts_x_n)

# %%
confusion_matrix(test_y, prY)

# %%
fpr, tpr, _ = metrics.roc_curve(np.array(test_y), prY_prob[:,1])

# %%
auc = metrics.auc(fpr,tpr)
auc

# %%
plt.plot(fpr, tpr)

# %% [markdown]
# ### Random Forest Classifier with Negayion and Uncertainty:

# %%
rfc= RandomForestClassifier(random_state=110)

# %%
prY = rfc.fit(tr_x, train_y).predict(ts_x)

# %%
prY_prob = rfc.fit(tr_x, train_y).predict_proba(ts_x)

# %%
confusion_matrix(test_y, prY)

# %%
fpr, tpr, _ = metrics.roc_curve(np.array(test_y), prY_prob[:,1])

# %%
auc = metrics.auc(fpr,tpr)
auc

# %%
plt.plot(fpr, tpr)

# %%
feature_importances = pd.DataFrame(rfc.feature_importances_,
                                   index = tr_x.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)

# %%
feature_importances.reset_index(inplace = True)

# %%
feature_importances

# %%
#feature_importances = feature_importances[0:3]

# %%
#from pyplot import *

fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (6,8), sharex=True, sharey=True)
axes.barh(feature_importances['index'],feature_importances['importance'],  align = 'center', color = "orange")
axes.set_title("Important Predictors of Diabetes", fontsize = 16)
axes.invert_yaxis()
plt.tight_layout

# %%
fig.savefig('Importance.png', bbox_inches = 'tight')

# %% [markdown]
# ### Random Forest Classifier without Negayion and Uncertainty:

# %%
rfc= RandomForestClassifier(random_state=110)

# %%
prY = rfc.fit(tr_x_n, train_y).predict(ts_x_n)

# %%
prY_prob = rfc.fit(tr_x_n, train_y).predict_proba(ts_x_n)

# %%
confusion_matrix(test_y, prY)

# %%
fpr, tpr, _ = metrics.roc_curve(np.array(test_y), prY_prob[:,1])

# %%
auc = metrics.auc(fpr,tpr)
auc

# %%
plt.plot(fpr, tpr)

# %%
feature_importances = pd.DataFrame(rfc.feature_importances_,
                                   index = tr_x_n.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)

# %%
feature_importances.reset_index(inplace = True)

# %%
feature_importances
