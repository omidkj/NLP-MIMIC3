# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline
# Out:
# C:\Users\banae\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
df_adm = pd.read_csv('ADMISSIONS.csv', parse_dates = ['ADMITTIME', 'DISCHTIME',
       'DEATHTIME'], infer_datetime_format = True, engine = "c")

# %%
df_adm = df_adm[['SUBJECT_ID', 'HADM_ID', 'ADMITTIME', 'DISCHTIME',
       'DEATHTIME', 'ADMISSION_TYPE']]

# %%
df_adm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58976 entries, 0 to 58975
# Data columns (total 6 columns):
# SUBJECT_ID        58976 non-null int64
# HADM_ID           58976 non-null int64
# ADMITTIME         58976 non-null datetime64[ns]
# DISCHTIME         58976 non-null datetime64[ns]
# DEATHTIME         5854 non-null datetime64[ns]
# ADMISSION_TYPE    58976 non-null object
# dtypes: datetime64[ns](3), int64(2), object(1)
# memory usage: 2.7+ MB

# %% [markdown]
# #### The next step is to get the next unplanned admission date if it exists. sort by subject_ID and admission date

# %%
df_adm = df_adm.sort_values(['SUBJECT_ID','ADMITTIME'])
df_adm = df_adm.reset_index(drop = True)

# %%
df_adm.tail(10)
# Out:
#        SUBJECT_ID  HADM_ID           ADMITTIME           DISCHTIME DEATHTIME  \
# 58966       99973   150202 2180-11-27 02:30:00 2180-12-01 13:42:00       NaT
# 58967       99982   151454 2156-11-28 11:56:00 2156-12-08 13:45:00       NaT
# 58968       99982   112748 2157-01-05 17:27:00 2157-01-12 13:00:00       NaT
# 58969       99982   183791 2157-02-16 17:31:00 2157-02-22 20:36:00       NaT
# 58970       99983   117390 2193-04-26 11:35:00 2193-04-29 13:30:00       NaT
# 58971       99985   176670 2181-01-27 02:47:00 2181-02-12 17:05:00       NaT
# 58972       99991   151118 2184-12-24 08:30:00 2185-01-05 12:15:00       NaT
# 58973       99992   197084 2144-07-25 18:03:00 2144-07-28 17:56:00       NaT
# 58974       99995   137810 2147-02-08 08:00:00 2147-02-11 13:15:00       NaT
# 58975       99999   113369 2117-12-30 07:15:00 2118-01-04 16:30:00       NaT
#
#       ADMISSION_TYPE
# 58966      EMERGENCY
# 58967      EMERGENCY
# 58968      EMERGENCY
# 58969      EMERGENCY
# 58970      EMERGENCY
# 58971      EMERGENCY
# 58972       ELECTIVE
# 58973      EMERGENCY
# 58974       ELECTIVE
# 58975       ELECTIVE

# %%
#### It is the way we want it to be

# %%
df_adm['NEXT_ADMITTIME'] = df_adm.groupby('SUBJECT_ID').ADMITTIME.shift(-1)

# %%
# get the next admission type
df_adm['NEXT_ADMISSION_TYPE'] = df_adm.groupby('SUBJECT_ID').ADMISSION_TYPE.shift(-1)

# %%
df_adm.head(200)
# Out:
#      SUBJECT_ID  HADM_ID           ADMITTIME           DISCHTIME  \
# 0             2   163353 2138-07-17 19:04:00 2138-07-21 15:48:00
# 1             3   145834 2101-10-20 19:08:00 2101-10-31 13:58:00
# 2             4   185777 2191-03-16 00:28:00 2191-03-23 18:41:00
# 3             5   178980 2103-02-02 04:31:00 2103-02-04 12:15:00
# 4             6   107064 2175-05-30 07:15:00 2175-06-15 16:00:00
# 193         145   198161 2144-03-29 01:44:00 2144-07-14 16:15:00
# 194         145   138459 2145-02-15 17:19:00 2145-02-22 13:30:00
# 195         146   190707 2119-12-19 12:15:00 2120-01-10 13:08:00
# 196         147   103631 2158-06-24 18:50:00 2158-07-21 14:10:00
# 197         148   199488 2107-09-05 14:58:00 2107-10-08 13:35:00
# 198         149   154869 2135-02-18 19:16:00 2135-02-26 17:00:00
# 199         150   108732 2161-07-09 17:54:00 2161-07-14 14:00:00
#
#               DEATHTIME ADMISSION_TYPE      NEXT_ADMITTIME NEXT_ADMISSION_TYPE
# 0                   NaT        NEWBORN                 NaT                 NaN
# 1                   NaT      EMERGENCY                 NaT                 NaN
# 2                   NaT      EMERGENCY                 NaT                 NaN
# 3                   NaT        NEWBORN                 NaT                 NaN
# 4                   NaT       ELECTIVE                 NaT                 NaN
# 5                   NaT        NEWBORN                 NaT                 NaN
# 6                   NaT        NEWBORN                 NaT                 NaN
# 7   2149-11-14 10:15:00      EMERGENCY                 NaT                 NaN
# 8                   NaT        NEWBORN                 NaT                 NaN
# 9                   NaT      EMERGENCY                 NaT                 NaN
# 10  2104-08-20 02:57:00       ELECTIVE                 NaT                 NaN
# 11                  NaT      EMERGENCY                 NaT                 NaN
# 12                  NaT        NEWBORN                 NaT                 NaN
# 13                  NaT       ELECTIVE 2135-05-09 14:11:00           EMERGENCY
# 14                  NaT      EMERGENCY                 NaT                 NaN
# 15                  NaT      EMERGENCY                 NaT                 NaN
# 16                  NaT      EMERGENCY                 NaT                 NaN
# 17                  NaT       ELECTIVE                 NaT                 NaN
# 18                  NaT      EMERGENCY 2135-01-30 20:50:00           EMERGENCY
# 19  2135-02-08 02:08:00      EMERGENCY                 NaT                 NaN
# 20                  NaT      EMERGENCY                 NaT                 NaN
# 21                  NaT       ELECTIVE 2157-10-18 19:34:00           EMERGENCY
# 22                  NaT      EMERGENCY                 NaT                 NaN
# 23                  NaT      EMERGENCY                 NaT                 NaN
# 24                  NaT      EMERGENCY                 NaT                 NaN
# 25                  NaT      EMERGENCY                 NaT                 NaN
# 26                  NaT        NEWBORN                 NaT                 NaN
# 27                  NaT       ELECTIVE                 NaT                 NaN
# 28                  NaT         URGENT                 NaT                 NaN
# 29  2108-08-30 15:00:00      EMERGENCY                 NaT                 NaN
# ..                  ...            ...                 ...                 ...
# 170                 NaT        NEWBORN                 NaT                 NaN
# 171                 NaT      EMERGENCY                 NaT                 NaN
# 172                 NaT        NEWBORN                 NaT                 NaN
# 173                 NaT      EMERGENCY                 NaT                 NaN
# 174                 NaT      EMERGENCY 2119-11-14 12:00:00           EMERGENCY
# 175                 NaT      EMERGENCY                 NaT                 NaN
# 176                 NaT        NEWBORN                 NaT                 NaN
# 177                 NaT      EMERGENCY                 NaT                 NaN
# 178                 NaT      EMERGENCY                 NaT                 NaN
# 179                 NaT       ELECTIVE                 NaT                 NaN
# 180                 NaT      EMERGENCY 2174-05-17 09:00:00            ELECTIVE
# 181                 NaT       ELECTIVE                 NaT                 NaN
# 182                 NaT       ELECTIVE                 NaT                 NaN
# 183                 NaT      EMERGENCY                 NaT                 NaN
# 184                 NaT       ELECTIVE 2133-12-21 23:52:00           EMERGENCY
# 185                 NaT      EMERGENCY 2134-03-01 07:15:00            ELECTIVE
# 186                 NaT       ELECTIVE                 NaT                 NaN
# 187                 NaT        NEWBORN                 NaT                 NaN
# 188                 NaT      EMERGENCY                 NaT                 NaN
# 189 2140-11-09 20:36:00      EMERGENCY                 NaT                 NaN
# 190                 NaT       ELECTIVE                 NaT                 NaN
# 191                 NaT      EMERGENCY                 NaT                 NaN
# 192                 NaT      EMERGENCY                 NaT                 NaN
# 193                 NaT      EMERGENCY 2145-02-15 17:19:00           EMERGENCY
# 194                 NaT      EMERGENCY                 NaT                 NaN
# 195                 NaT         URGENT                 NaT                 NaN
# 196                 NaT      EMERGENCY                 NaT                 NaN
# 197                 NaT      EMERGENCY                 NaT                 NaN
# 198                 NaT      EMERGENCY                 NaT                 NaN
# 199                 NaT      EMERGENCY                 NaT                 NaN
#
# [200 rows x 8 columns]

# %%
#### Gain we can make sure that it is working the way we want.

# %%
#### we want to predict UNPLANNED re-admissions, so we should filter out the ELECTIVE next admissions.

# %%
# get rows where next admission is elective and replace with naT or nan

# %%
rows = df_adm.NEXT_ADMISSION_TYPE == 'ELECTIVE'
df_adm.loc[rows,'NEXT_ADMITTIME'] = pd.NaT
df_adm.loc[rows,'NEXT_ADMISSION_TYPE'] = np.NaN

# %%
df_adm.head(200)
# Out:
#      SUBJECT_ID  HADM_ID           ADMITTIME           DISCHTIME  \
# 0             2   163353 2138-07-17 19:04:00 2138-07-21 15:48:00
# 1             3   145834 2101-10-20 19:08:00 2101-10-31 13:58:00
# 2             4   185777 2191-03-16 00:28:00 2191-03-23 18:41:00
# 3             5   178980 2103-02-02 04:31:00 2103-02-04 12:15:00
# 4             6   107064 2175-05-30 07:15:00 2175-06-15 16:00:00
# 5             7   118037 2121-05-23 15:05:00 2121-05-27 11:57:00
# 6             8   159514 2117-11-20 10:22:00 2117-11-24 14:20:00
# 7             9   150750 2149-11-09 13:06:00 2149-11-14 10:15:00
# 8            10   184167 2103-06-28 11:36:00 2103-07-06 12:10:00
# 9            11   194540 2178-04-16 06:18:00 2178-05-11 19:00:00
# 10           12   112213 2104-08-07 10:15:00 2104-08-20 02:57:00
# 11           13   143045 2167-01-08 18:43:00 2167-01-15 15:15:00
# 12           16   103251 2178-02-03 06:35:00 2178-02-05 10:51:00
# 13           17   194023 2134-12-27 07:15:00 2134-12-31 16:05:00
# 14           17   161087 2135-05-09 14:11:00 2135-05-13 14:40:00
# 15           18   188822 2167-10-02 11:18:00 2167-10-04 16:15:00
# 16           19   109235 2108-08-05 16:25:00 2108-08-11 11:29:00
# 17           20   157681 2183-04-28 09:45:00 2183-05-03 14:45:00
# 18           21   109451 2134-09-11 12:17:00 2134-09-24 16:15:00
# 19           21   111970 2135-01-30 20:50:00 2135-02-08 02:08:00
# 20           22   165315 2196-04-09 12:26:00 2196-04-10 15:54:00
# 21           23   152223 2153-09-03 07:15:00 2153-09-08 19:10:00
# 22           23   124321 2157-10-18 19:34:00 2157-10-25 14:00:00
# 6                   NaT        NEWBORN                 NaT                 NaN
# 7   2149-11-14 10:15:00      EMERGENCY                 NaT                 NaN
# 8                   NaT        NEWBORN                 NaT                 NaN
# 9                   NaT      EMERGENCY                 NaT                 NaN
# 10  2104-08-20 02:57:00       ELECTIVE                 NaT                 NaN
# 11                  NaT      EMERGENCY                 NaT                 NaN
# 12                  NaT        NEWBORN                 NaT                 NaN
# 13                  NaT       ELECTIVE 2135-05-09 14:11:00           EMERGENCY
# 14                  NaT      EMERGENCY                 NaT                 NaN
# 15                  NaT      EMERGENCY                 NaT                 NaN
# 16                  NaT      EMERGENCY                 NaT                 NaN
# 17                  NaT       ELECTIVE                 NaT                 NaN
# 18                  NaT      EMERGENCY 2135-01-30 20:50:00           EMERGENCY
# 19  2135-02-08 02:08:00      EMERGENCY                 NaT                 NaN
# 20                  NaT      EMERGENCY                 NaT                 NaN
# 21                  NaT       ELECTIVE 2157-10-18 19:34:00           EMERGENCY
# 22                  NaT      EMERGENCY                 NaT                 NaN
# 23                  NaT      EMERGENCY                 NaT                 NaN
# 24                  NaT      EMERGENCY                 NaT                 NaN
# 25                  NaT      EMERGENCY                 NaT                 NaN
# 26                  NaT        NEWBORN                 NaT                 NaN
# 27                  NaT       ELECTIVE                 NaT                 NaN
# 28                  NaT         URGENT                 NaT                 NaN
# 29  2108-08-30 15:00:00      EMERGENCY                 NaT                 NaN
# ..                  ...            ...                 ...                 ...
# 170                 NaT        NEWBORN                 NaT                 NaN
# 171                 NaT      EMERGENCY                 NaT                 NaN
# 172                 NaT        NEWBORN                 NaT                 NaN
# 173                 NaT      EMERGENCY                 NaT                 NaN
# 174                 NaT      EMERGENCY 2119-11-14 12:00:00           EMERGENCY
# 175                 NaT      EMERGENCY                 NaT                 NaN
# 176                 NaT        NEWBORN                 NaT                 NaN
# 177                 NaT      EMERGENCY                 NaT                 NaN
# 178                 NaT      EMERGENCY                 NaT                 NaN
# 179                 NaT       ELECTIVE                 NaT                 NaN
# 180                 NaT      EMERGENCY                 NaT                 NaN
# 181                 NaT       ELECTIVE                 NaT                 NaN
# 182                 NaT       ELECTIVE                 NaT                 NaN
# 183                 NaT      EMERGENCY                 NaT                 NaN
# 184                 NaT       ELECTIVE 2133-12-21 23:52:00           EMERGENCY
# 185                 NaT      EMERGENCY                 NaT                 NaN
# 186                 NaT       ELECTIVE                 NaT                 NaN
# 187                 NaT        NEWBORN                 NaT                 NaN
# 188                 NaT      EMERGENCY                 NaT                 NaN
# 189 2140-11-09 20:36:00      EMERGENCY                 NaT                 NaN
# 190                 NaT       ELECTIVE                 NaT                 NaN
# 191                 NaT      EMERGENCY                 NaT                 NaN
# 192                 NaT      EMERGENCY                 NaT                 NaN
# 193                 NaT      EMERGENCY 2145-02-15 17:19:00           EMERGENCY
# 194                 NaT      EMERGENCY                 NaT                 NaN
# 195                 NaT         URGENT                 NaT                 NaN
# 196                 NaT      EMERGENCY                 NaT                 NaN
# 197                 NaT      EMERGENCY                 NaT                 NaN
# 198                 NaT      EMERGENCY                 NaT                 NaN
# 176         131   171781 2143-12-07 12:19:00 2143-12-12 09:00:00
# 177         132   160192 2115-05-06 21:53:00 2115-05-25 12:10:00
# 178         133   191817 2165-05-06 18:38:00 2165-05-16 15:25:00
# 179         134   167887 2127-01-14 07:15:00 2127-01-24 14:55:00
# 180         135   192180 2173-05-18 11:06:00 2173-05-26 14:30:00
# 181         135   199634 2174-05-17 09:00:00 2174-05-21 14:00:00
# 182         136   184644 2103-05-09 07:15:00 2103-05-14 11:33:00
# 183         137   151583 2191-11-10 13:57:00 2191-11-24 12:23:00
# 184         138   108120 2131-10-31 08:00:00 2131-11-06 12:54:00
# 185         138   188284 2133-12-21 23:52:00 2134-01-11 13:00:00
# 186         138   105764 2134-03-01 07:15:00 2134-03-07 11:44:00
# 187         139   195786 2177-09-30 20:32:00 2177-12-10 10:10:00
# 188         140   165618 2160-09-21 08:31:00 2160-09-23 12:00:00
# 189         141   168006 2140-11-06 11:07:00 2140-11-09 20:36:00
# 190         142   131357 2143-04-01 07:15:00 2143-04-05 18:40:00
# 191         143   143808 2155-01-17 21:40:00 2155-02-02 15:00:00
# 192         144   137432 2197-07-14 20:18:00 2197-08-01 13:15:00
# 193         145   198161 2144-03-29 01:44:00 2144-07-14 16:15:00
# 194         145   138459 2145-02-15 17:19:00 2145-02-22 13:30:00
# 195         146   190707 2119-12-19 12:15:00 2120-01-10 13:08:00
# 196         147   103631 2158-06-24 18:50:00 2158-07-21 14:10:00
# 197         148   199488 2107-09-05 14:58:00 2107-10-08 13:35:00
# 198         149   154869 2135-02-18 19:16:00 2135-02-26 17:00:00
# 199         150   108732 2161-07-09 17:54:00 2161-07-14 14:00:00
#
#               DEATHTIME ADMISSION_TYPE      NEXT_ADMITTIME NEXT_ADMISSION_TYPE
# 0                   NaT        NEWBORN                 NaT                 NaN
# 1                   NaT      EMERGENCY                 NaT                 NaN
# 2                   NaT      EMERGENCY                 NaT                 NaN
# 3                   NaT        NEWBORN                 NaT                 NaN
# 4                   NaT       ELECTIVE                 NaT                 NaN
# 5                   NaT        NEWBORN                 NaT                 NaN
# 6                   NaT        NEWBORN                 NaT                 NaN
# 7   2149-11-14 10:15:00      EMERGENCY                 NaT                 NaN
# 8                   NaT        NEWBORN                 NaT                 NaN
# 9                   NaT      EMERGENCY                 NaT                 NaN
# 10  2104-08-20 02:57:00       ELECTIVE                 NaT                 NaN
# 11                  NaT      EMERGENCY                 NaT                 NaN
# 12                  NaT        NEWBORN                 NaT                 NaN
# 13                  NaT       ELECTIVE 2135-05-09 14:11:00           EMERGENCY
# 14                  NaT      EMERGENCY                 NaT                 NaN
# 15                  NaT      EMERGENCY                 NaT                 NaN
# 16                  NaT      EMERGENCY                 NaT                 NaN
# 17                  NaT       ELECTIVE                 NaT                 NaN
# 18                  NaT      EMERGENCY 2135-01-30 20:50:00           EMERGENCY
# 19  2135-02-08 02:08:00      EMERGENCY                 NaT                 NaN
# 20                  NaT      EMERGENCY                 NaT                 NaN
# 21                  NaT       ELECTIVE 2157-10-18 19:34:00           EMERGENCY
# 22                  NaT      EMERGENCY                 NaT                 NaN
# 23                  NaT      EMERGENCY                 NaT                 NaN
# 24                  NaT      EMERGENCY                 NaT                 NaN
# 25                  NaT      EMERGENCY                 NaT                 NaN
# 26                  NaT        NEWBORN                 NaT                 NaN
# 27                  NaT       ELECTIVE                 NaT                 NaN
# 28                  NaT         URGENT                 NaT                 NaN
# 29  2108-08-30 15:00:00      EMERGENCY                 NaT                 NaN
# ..                  ...            ...                 ...                 ...
# 170                 NaT        NEWBORN                 NaT                 NaN
# 171                 NaT      EMERGENCY                 NaT                 NaN
# 172                 NaT        NEWBORN                 NaT                 NaN
# 173                 NaT      EMERGENCY                 NaT                 NaN
# 174                 NaT      EMERGENCY 2119-11-14 12:00:00           EMERGENCY
# 175                 NaT      EMERGENCY                 NaT                 NaN
# 176                 NaT        NEWBORN                 NaT                 NaN
# 177                 NaT      EMERGENCY                 NaT                 NaN
# 178                 NaT      EMERGENCY                 NaT                 NaN
# 179                 NaT       ELECTIVE                 NaT                 NaN
# 180                 NaT      EMERGENCY                 NaT                 NaN
# 181                 NaT       ELECTIVE                 NaT                 NaN
# 182                 NaT       ELECTIVE                 NaT                 NaN
# 183                 NaT      EMERGENCY                 NaT                 NaN
# 184                 NaT       ELECTIVE 2133-12-21 23:52:00           EMERGENCY
# 185                 NaT      EMERGENCY                 NaT                 NaN
# 186                 NaT       ELECTIVE                 NaT                 NaN
# 187                 NaT        NEWBORN                 NaT                 NaN
# 188                 NaT      EMERGENCY                 NaT                 NaN
# 189 2140-11-09 20:36:00      EMERGENCY                 NaT                 NaN
# 190                 NaT       ELECTIVE                 NaT                 NaN
# 191                 NaT      EMERGENCY                 NaT                 NaN
# 192                 NaT      EMERGENCY                 NaT                 NaN
# 193                 NaT      EMERGENCY 2145-02-15 17:19:00           EMERGENCY
# 194                 NaT      EMERGENCY                 NaT                 NaN
# 195                 NaT         URGENT                 NaT                 NaN
# 196                 NaT      EMERGENCY                 NaT                 NaN
# 197                 NaT      EMERGENCY                 NaT                 NaN
# 198                 NaT      EMERGENCY                 NaT                 NaN
# 199                 NaT      EMERGENCY                 NaT                 NaN
#
# [200 rows x 8 columns]

# %%
df_adm['DAYS_NEXT_ADMIT']=  (df_adm.NEXT_ADMITTIME - df_adm.DISCHTIME).dt.total_seconds()/(24*60*60)

# %%
df_adm.head(200)
# Out:
#      SUBJECT_ID  HADM_ID           ADMITTIME           DISCHTIME  \
# 0             2   163353 2138-07-17 19:04:00 2138-07-21 15:48:00
# 1             3   145834 2101-10-20 19:08:00 2101-10-31 13:58:00
# 2             4   185777 2191-03-16 00:28:00 2191-03-23 18:41:00
# 3             5   178980 2103-02-02 04:31:00 2103-02-04 12:15:00
# 4             6   107064 2175-05-30 07:15:00 2175-06-15 16:00:00
# 5             7   118037 2121-05-23 15:05:00 2121-05-27 11:57:00
# 6             8   159514 2117-11-20 10:22:00 2117-11-24 14:20:00
# 7             9   150750 2149-11-09 13:06:00 2149-11-14 10:15:00
# 8            10   184167 2103-06-28 11:36:00 2103-07-06 12:10:00
# 9            11   194540 2178-04-16 06:18:00 2178-05-11 19:00:00
# 10           12   112213 2104-08-07 10:15:00 2104-08-20 02:57:00
# 194         145   138459 2145-02-15 17:19:00 2145-02-22 13:30:00
# 195         146   190707 2119-12-19 12:15:00 2120-01-10 13:08:00
# 196         147   103631 2158-06-24 18:50:00 2158-07-21 14:10:00
# 197         148   199488 2107-09-05 14:58:00 2107-10-08 13:35:00
# 198         149   154869 2135-02-18 19:16:00 2135-02-26 17:00:00
# 199         150   108732 2161-07-09 17:54:00 2161-07-14 14:00:00
#
#               DEATHTIME ADMISSION_TYPE      NEXT_ADMITTIME  \
# 0                   NaT        NEWBORN                 NaT
# 1                   NaT      EMERGENCY                 NaT
# 2                   NaT      EMERGENCY                 NaT
# 3                   NaT        NEWBORN                 NaT
# 4                   NaT       ELECTIVE                 NaT
# 5                   NaT        NEWBORN                 NaT
# 6                   NaT        NEWBORN                 NaT
# 7   2149-11-14 10:15:00      EMERGENCY                 NaT
# 8                   NaT        NEWBORN                 NaT
# 9                   NaT      EMERGENCY                 NaT
# 10  2104-08-20 02:57:00       ELECTIVE                 NaT
# 11                  NaT      EMERGENCY                 NaT
# 12                  NaT        NEWBORN                 NaT
# 13                  NaT       ELECTIVE 2135-05-09 14:11:00
# 14                  NaT      EMERGENCY                 NaT
# 15                  NaT      EMERGENCY                 NaT
# 16                  NaT      EMERGENCY                 NaT
# 17                  NaT       ELECTIVE                 NaT
# 18                  NaT      EMERGENCY 2135-01-30 20:50:00
# 19  2135-02-08 02:08:00      EMERGENCY                 NaT
# 20                  NaT      EMERGENCY                 NaT
# 21                  NaT       ELECTIVE 2157-10-18 19:34:00
# 22                  NaT      EMERGENCY                 NaT
# 23                  NaT      EMERGENCY                 NaT
# 24                  NaT      EMERGENCY                 NaT
# 25                  NaT      EMERGENCY                 NaT
# 26                  NaT        NEWBORN                 NaT
# 27                  NaT       ELECTIVE                 NaT
# 28                  NaT         URGENT                 NaT
# 29  2108-08-30 15:00:00      EMERGENCY                 NaT
# ..                  ...            ...                 ...
# 170                 NaT        NEWBORN                 NaT
# 171                 NaT      EMERGENCY                 NaT
# 172                 NaT        NEWBORN                 NaT
# 173                 NaT      EMERGENCY                 NaT
# 174                 NaT      EMERGENCY 2119-11-14 12:00:00
# 175                 NaT      EMERGENCY                 NaT
# 176                 NaT        NEWBORN                 NaT
# 177                 NaT      EMERGENCY                 NaT
# 178                 NaT      EMERGENCY                 NaT
# 179                 NaT       ELECTIVE                 NaT
# 180                 NaT      EMERGENCY                 NaT
# 181                 NaT       ELECTIVE                 NaT
# 182                 NaT       ELECTIVE                 NaT
# 183                 NaT      EMERGENCY                 NaT
# 184                 NaT       ELECTIVE 2133-12-21 23:52:00
# 185                 NaT      EMERGENCY                 NaT
# 186                 NaT       ELECTIVE                 NaT
# 187                 NaT        NEWBORN                 NaT
# 188                 NaT      EMERGENCY                 NaT
# 189 2140-11-09 20:36:00      EMERGENCY                 NaT
# 190                 NaT       ELECTIVE                 NaT
# 191                 NaT      EMERGENCY                 NaT
# 192                 NaT      EMERGENCY                 NaT
# 193                 NaT      EMERGENCY 2145-02-15 17:19:00
# 194                 NaT      EMERGENCY                 NaT
# 195                 NaT         URGENT                 NaT
# 196                 NaT      EMERGENCY                 NaT
# 197                 NaT      EMERGENCY                 NaT
# 198                 NaT      EMERGENCY                 NaT
# 199                 NaT      EMERGENCY                 NaT
#
#     NEXT_ADMISSION_TYPE  DAYS_NEXT_ADMIT
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# 5                   NaN              NaN
# 6                   NaN              NaN
# 7                   NaN              NaN
# 8                   NaN              NaN
# 9                   NaN              NaN
# 10                  NaN              NaN
# 11                  NaN              NaN
# 12                  NaN              NaN
# 13            EMERGENCY       128.920833
# 14                  NaN              NaN
# 15                  NaN              NaN
# 16                  NaN              NaN
# 17                  NaN              NaN
# 18            EMERGENCY       128.190972
# 19                  NaN              NaN
# 20                  NaN              NaN
# 21            EMERGENCY      1501.016667
# 22                  NaN              NaN
# 23                  NaN              NaN
# 24                  NaN              NaN
# 25                  NaN              NaN
# 26                  NaN              NaN
# 27                  NaN              NaN
# 28                  NaN              NaN
# 29                  NaN              NaN
# ..                  ...              ...
# 170                 NaN              NaN
# 171                 NaN              NaN
# 172                 NaN              NaN
# 173                 NaN              NaN
# 174           EMERGENCY         8.791667
# 175                 NaN              NaN
# 176                 NaN              NaN
# 177                 NaN              NaN
# 178                 NaN              NaN
# 179                 NaN              NaN
# 180                 NaN              NaN
# 181                 NaN              NaN
# 182                 NaN              NaN
# 183                 NaN              NaN
# 184           EMERGENCY       776.456944
# 185                 NaN              NaN
# 186                 NaN              NaN
# 187                 NaN              NaN
# 188                 NaN              NaN
# 189                 NaN              NaN
# 190                 NaN              NaN
# 191                 NaN              NaN
# 192                 NaN              NaN
# 193           EMERGENCY       216.044444
# 194                 NaN              NaN
# 195                 NaN              NaN
# 196                 NaN              NaN
# 197                 NaN              NaN
# 198                 NaN              NaN
# 199                 NaN              NaN
#
# [200 rows x 9 columns]

# %%
#### histogram of days between admissions.

# %%
use_cols = ['SUBJECT_ID', 'HADM_ID', 'CATEGORY', 'TEXT']

# %%
df_notes = pd.read_csv("NOTEEVENTS.csv",usecols= use_cols, low_memory = False, engine = "c")

# %%
df_notes.columns
# Out:
# Index(['SUBJECT_ID', 'HADM_ID', 'CATEGORY', 'TEXT'], dtype='object')

# %%
df_notes_dis_sum = df_notes.loc[df_notes.CATEGORY == 'Discharge summary']

# %%
#assert df_notes_dis_sum.duplicated(['HADM_ID']).sum() == 0

# %%
#### For simlicity I am going to use only the last discharge note:

# %%
df_notes_dis_sum_last = (df_notes_dis_sum.groupby(['SUBJECT_ID','HADM_ID']).nth(-1)).reset_index()

# %%
assert df_notes_dis_sum_last.duplicated(['HADM_ID']).sum() == 0, 'Multiple discharge summaries per admission'

# %%
df_adm_notes = pd.merge(df_adm, df_notes_dis_sum_last, on = ['SUBJECT_ID','HADM_ID'],how = 'left')

# %%
assert len(df_adm) == len(df_adm_notes), 'Number of rows increased'

# %%
df_adm_notes.TEXT.isnull().sum() / len(df_adm_notes)
# Out:
# 0.1059753119913185

# %%
#### 10.6 % of the admissions are missing

# %%
df_adm_notes.groupby('ADMISSION_TYPE').apply(lambda g: g.TEXT.isnull().sum())/df_adm_notes.groupby('ADMISSION_TYPE').size()
# Out:
# ADMISSION_TYPE
# ELECTIVE     0.048663
# EMERGENCY    0.037983
# NEWBORN      0.536691
# URGENT       0.042665
# dtype: float64

# %%
#### 53% of the NEWBORN admissions were missing discharge summaries vs ~4% for the others.

# %%
df_adm_notes_clean = df_adm_notes.loc[df_adm_notes.ADMISSION_TYPE != "NEWBORN"]

# %%
df_adm_notes_clean['OUTPUT_LABEL'] = (df_adm_notes_clean.DAYS_NEXT_ADMIT < 30).astype('int')
# Out:
# C:\Users\banae\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_adm_notes_clean.head()
# Out:
#    SUBJECT_ID  HADM_ID           ADMITTIME           DISCHTIME  \
# 1           3   145834 2101-10-20 19:08:00 2101-10-31 13:58:00
# 2           4   185777 2191-03-16 00:28:00 2191-03-23 18:41:00
# 4           6   107064 2175-05-30 07:15:00 2175-06-15 16:00:00
# 7           9   150750 2149-11-09 13:06:00 2149-11-14 10:15:00
# 9          11   194540 2178-04-16 06:18:00 2178-05-11 19:00:00
#
#             DEATHTIME ADMISSION_TYPE NEXT_ADMITTIME NEXT_ADMISSION_TYPE  \
# 1                 NaT      EMERGENCY            NaT                 NaN
# 2                 NaT      EMERGENCY            NaT                 NaN
# 4                 NaT       ELECTIVE            NaT                 NaN
# 7 2149-11-14 10:15:00      EMERGENCY            NaT                 NaN
# 9                 NaT      EMERGENCY            NaT                 NaN
#
#    DAYS_NEXT_ADMIT           CATEGORY  \
# 1              NaN  Discharge summary
# 2              NaN  Discharge summary
# 4              NaN  Discharge summary
# 7              NaN  Discharge summary
# 9              NaN  Discharge summary
#
#                                                 TEXT  OUTPUT_LABEL
# 1  Admission Date:  [**2101-10-20**]     Discharg...             0
# 2  Admission Date:  [**2191-3-16**]     Discharge...             0
# 4  Admission Date: [**2175-5-30**]        Dischar...             0
# 7  Name:  [**Known lastname 10050**], [**Known fi...             0
# 9  Admission Date:  [**2178-4-16**]              ...             0

# %%
df_adm_notes_clean.OUTPUT_LABEL.value_counts()
# Out:
# 0    48109
# 1     3004
# Name: OUTPUT_LABEL, dtype: int64

# %%
#### This indicates that we have an imbalanced dataset, which is a common occurrence in healthcare data science.

# %%
# shuffle the samples

# %%
df_adm_notes_clean = df_adm_notes_clean.sample(n = len(df_adm_notes_clean), random_state = 42)

# %%
df_adm_notes_clean = df_adm_notes_clean.reset_index(drop = True)

# %%
# Save 30% of the data as validation and test data 
df_valid = df_adm_notes_clean.sample(frac=0.2,random_state=42)

# %%
# df_test = df_valid_test.sample(frac = 0.5, random_state = 42)
df_valid = df_valid_test.drop(df_test.index)
# use the rest of the data as training data
# df_train_all=df_adm_notes_clean.drop(df_valid_test.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-de85e2b40e71> in <module>()
#       1 # df_test = df_valid_test.sample(frac = 0.5, random_state = 42)
# ----> 2 df_valid = df_valid_test.drop(df_test.index)
#       3 # use the rest of the data as training data
#       4 # df_train_all=df_adm_notes_clean.drop(df_valid_test.index)
#
# NameError: name 'df_valid_test' is not defined

# %%
# split the training data into positive and negative
rows_pos = df_train_all.OUTPUT_LABEL == 1
df_train_pos = df_train_all.loc[rows_pos]
df_train_neg = df_train_all.loc[~rows_pos]

# %%
# merge the balanced data
df_train = pd.concat([df_train_pos, df_train_neg.sample(n = len(df_train_pos), random_state = 42)],axis = 0)

# %%
# merge the balanced data
df_train_DNN = pd.concat([df_train_pos, df_train_neg.sample(n = 3* len(df_train_pos), random_state = 42)],axis = 0)

# %%
# shuffle the order of training samples 
df_train = df_train.sample(n = len(df_train), random_state = 42).reset_index(drop = True)
df_train_DNN = df_train_DNN.sample(n = len(df_train_DNN), random_state = 42).reset_index(drop = True)

# %%
#### Preprocess the unstructured notes using a bag-of-words approach

# %%
def preprocess_text(df):
    # This function preprocesses the text by filling not a number and replacing new lines ('\n') and carriage returns ('\r')
    df.TEXT = df.TEXT.fillna(' ')
    df.TEXT = df.TEXT.str.replace('\n',' ')
    df.TEXT = df.TEXT.str.replace('\r',' ')
    return df

# %%
# preprocess the text to deal with known issues
df_train = preprocess_text(df_train)
df_valid = preprocess_text(df_valid)
#df_test = preprocess_text(df_test)
df_train_DNN = preprocess_text(df_train_DNN)

# %%
import nltk
# nltk.download('punkt')
# nltk.download('wordnet')
from nltk import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.util import ngrams


# sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn import metrics

from numpy import array
from scipy.sparse import csr_matrix
from time import time

# keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.callbacks import TensorBoard

# %%
### We will write our own tokenizer function to
### replace punctuation with spaces
### replace numbers with spaces
### lower case all words

# %%
df_train.TEXT[0]

# %%
import string
PS = PorterStemmer()
WL = WordNetLemmatizer()
def tokenizer_better(text):
    # tokenize the text by replacing punctuation and numbers with spaces and lowercase all words
    
    punc_list = string.punctuation+'0123456789'
    t = str.maketrans(dict.fromkeys(punc_list, " "))
    text = text.lower().translate(t)
    tokens = word_tokenize(text)
    
    tokens = [PS.stem(word) for word in tokens] ##Stemming
    tokens = [WL.lemmatize(word) for word in tokens] ##Lemmatization  try with pos ='v'
    return tokens

# %% [markdown]
# #### We will use the built in CountVectorizer from scikit-learn package. This vectorizer simply counts how many times each word occurs in the note. There is also a TfidfVectorizer which takes into how often words are used across all notes, but for this project let’s use the simpler one (I got similar results with the second one too).

# %%
vocabulary_size = 20000

# %% [markdown]
# ### Only to find Stop-Words:

# %%
# Only to find Stop-Words: 


# fit our vectorizer. This will take a while depending on your computer. 
# vect = CountVectorizer(max_features = 3000, tokenizer = tokenizer_better)
# vect.fit(df_train.TEXT.values)
# X_train_tf = vect.transform(df_train.TEXT.values)

# %% [markdown]
# #### Finding most frequent words:

# %%
## sum_words = X_train_tf.sum(axis=0) 
## words_freq = [(word, sum_words[0, idx]) for word, idx in     vect.vocabulary_.items()]
## words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
## words_freq_plot = words_freq[:30]
## values = [value[0] for value in words_freq_plot]
## freq = [value[1] for value in words_freq_plot]
## fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (6,8), sharex=True)
## plt.barh(range(len(values)),freq, align = 'center')
## plt.yticks(range(len(values)),values)
## plt.title("Top 30 Frequent Words")
## plt.gca().invert_yaxis()
## plt.xlabel('Frequncy')
## plt.tight_layout()
## plt.show()

# %%
my_stop_words = ['the','and','to','of','was','with','a','on','in','for','name',
                 'is','patient','s','he','at','as','or','one','she','his','her','am',
                 'were','you','pt','pm','by','be','had','your','this','date',
                 'from','there','an','that','p','are','have','has','h','but','o',
                 'namepattern','which','every','also']

# %%
vect = CountVectorizer(max_features = 3000, 
                       tokenizer = tokenizer_better, 
                       stop_words = my_stop_words,
                       ngram_range= (1,3))
vect.fit(df_train.TEXT.values)

# %%
X_train_tf = vect.transform(df_train.TEXT.values)
X_valid_tf = vect.transform(df_valid.TEXT.values)

# Response:

y_train = df_train.OUTPUT_LABEL
y_valid = df_valid.OUTPUT_LABEL

# %%
vect_DNN = CountVectorizer(max_features = 3000,
                           tokenizer = tokenizer_better,
                           stop_words = my_stop_words,
                           ngram_range= (1,3))
vect_DNN.fit(df_train_DNN.TEXT.values)
X_train_DNN_tf = vect_DNN.transform(df_train_DNN.TEXT.values)

# %%
# X_train_DNN_tf = vect_DNN.transform(df_train_DNN.TEXT.values)
X_valid_DNN_tf = vect_DNN.transform(df_valid.TEXT.values)


# Response:

y_train_DNN = df_train_DNN.OUTPUT_LABEL
y_valid_DNN = y_valid

# %%
#### Step 3: Build a simple predictive model

# %%
# logistic regression

clf=LogisticRegression(C = 0.0001, penalty = 'l2', random_state = 42)
clf.fit(X_train_tf, y_train)

# %%
y_valid_preds = clf.predict_proba(X_valid_tf)[:, 1]

# %%
fpr, tpr, _ = metrics.roc_curve(np.array(y_valid), y_valid_preds)

# %%
auc = metrics.auc(fpr,tpr)
auc

# %%
y_train_binary = to_categorical(y_train)
y_valid_binary = to_categorical(y_valid)

# %%
X_train_Array = X_train_tf.todense()
X_valid_Array = X_valid_tf.todense()

# %%
X_train_DNN_Array = X_train_DNN_tf.todense()
y_train_DNN_binary = to_categorical(y_train_DNN)

# %%
model = Sequential()
model.add(Dense(500, input_dim = X_train_tf.shape[1] , activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(1000, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(500, activation = 'relu'))
model.add(Dense(2, activation = 'softmax'))

# %%
model.compile(optimizer=Adam(0.00001), loss= 'categorical_crossentropy', metrics=['accuracy'])

# %%
tensorboard = TensorBoard(log_dir = 'log/{}'.format(time()))

# %%
model.fit(X_train_Array, y_train_binary, epochs=500, batch_size=128, validation_data=(X_valid_Array, y_valid_binary), callbacks= [tensorboard])

# %%
y_pred = model.predict_proba(X_valid_Array)
fpr, tpr, _ = metrics.roc_curve(np.array(y_valid), y_pred[:,1])
auc = metrics.auc(fpr,tpr)
auc

# %% [markdown]
# ### Imbalanced Data:

# %%
model.fit(X_train_DNN_Array, y_train_DNN_binary, epochs=500, batch_size=128, class_weight = {0:1, 1:3}, validation_data=(X_valid_Array, y_valid_binary))

# %%
y_pred = model.predict_proba(X_valid_Array)
fpr, tpr, _ = metrics.roc_curve(np.array(y_valid), y_pred[:,1])
auc = metrics.auc(fpr,tpr)
auc
